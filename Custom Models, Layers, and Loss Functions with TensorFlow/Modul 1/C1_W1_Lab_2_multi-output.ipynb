# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 945us/sample - loss: 274.9141 - y1_output_loss: 128.6840 - y2_output_loss: 143.6117 - y1_output_root_mean_squared_error: 11.3989 - y2_output_root_mean_squared_error: 12.0408 - val_loss: 25.4445 - val_y1_output_loss: 12.8139 - val_y2_output_loss: 12.2215 - val_y1_output_root_mean_squared_error: 3.6113 - val_y2_output_root_mean_squared_error: 3.5218
# Epoch 2/500
# 614/614 [==============================] - 0s 168us/sample - loss: 33.3327 - y1_output_loss: 12.7261 - y2_output_loss: 21.1815 - y1_output_root_mean_squared_error: 3.5503 - y2_output_root_mean_squared_error: 4.5528 - val_loss: 37.7492 - val_y1_output_loss: 9.4449 - val_y2_output_loss: 27.7203 - val_y1_output_root_mean_squared_error: 3.1098 - val_y2_output_root_mean_squared_error: 5.2989
# Epoch 3/500
# 614/614 [==============================] - 0s 149us/sample - loss: 27.6078 - y1_output_loss: 10.9735 - y2_output_loss: 17.3490 - y1_output_root_mean_squared_error: 3.2709 - y2_output_root_mean_squared_error: 4.1121 - val_loss: 111.1596 - val_y1_output_loss: 23.2798 - val_y2_output_loss: 86.6091 - val_y1_output_root_mean_squared_error: 4.8577 - val_y2_output_root_mean_squared_error: 9.3575
# Epoch 4/500
# 614/614 [==============================] - 0s 142us/sample - loss: 28.1568 - y1_output_loss: 10.2503 - y2_output_loss: 17.7134 - y1_output_root_mean_squared_error: 3.2130 - y2_output_root_mean_squared_error: 4.2230 - val_loss: 14.5831 - val_y1_output_loss: 6.8150 - val_y2_output_loss: 7.2634 - val_y1_output_root_mean_squared_error: 2.6545 - val_y2_output_root_mean_squared_error: 2.7454
# Epoch 5/500
# 614/614 [==============================] - 0s 144us/sample - loss: 26.2600 - y1_output_loss: 10.1929 - y2_output_loss: 16.4123 - y1_output_root_mean_squared_error: 3.1669 - y2_output_root_mean_squared_error: 4.0287 - val_loss: 59.1420 - val_y1_output_loss: 18.5706 - val_y2_output_loss: 39.0816 - val_y1_output_root_mean_squared_error: 4.3673 - val_y2_output_root_mean_squared_error: 6.3300
# Epoch 6/500
# 614/614 [==============================] - 0s 145us/sample - loss: 26.0285 - y1_output_loss: 9.7942 - y2_output_loss: 16.4948 - y1_output_root_mean_squared_error: 3.1107 - y2_output_root_mean_squared_error: 4.0438 - val_loss: 38.2171 - val_y1_output_loss: 12.4831 - val_y2_output_loss: 24.8101 - val_y1_output_root_mean_squared_error: 3.5760 - val_y2_output_root_mean_squared_error: 5.0428
# Epoch 7/500
# 614/614 [==============================] - 0s 152us/sample - loss: 24.5018 - y1_output_loss: 9.4656 - y2_output_loss: 14.8456 - y1_output_root_mean_squared_error: 3.0888 - y2_output_root_mean_squared_error: 3.8680 - val_loss: 13.5699 - val_y1_output_loss: 6.1092 - val_y2_output_loss: 6.9946 - val_y1_output_root_mean_squared_error: 2.5119 - val_y2_output_root_mean_squared_error: 2.6945
# Epoch 8/500
# 614/614 [==============================] - 0s 156us/sample - loss: 27.3185 - y1_output_loss: 9.9363 - y2_output_loss: 17.7596 - y1_output_root_mean_squared_error: 3.1358 - y2_output_root_mean_squared_error: 4.1815 - val_loss: 98.8684 - val_y1_output_loss: 18.9332 - val_y2_output_loss: 77.5360 - val_y1_output_root_mean_squared_error: 4.4139 - val_y2_output_root_mean_squared_error: 8.9099
# Epoch 9/500
# 614/614 [==============================] - 0s 148us/sample - loss: 33.5615 - y1_output_loss: 10.8972 - y2_output_loss: 22.8260 - y1_output_root_mean_squared_error: 3.2930 - y2_output_root_mean_squared_error: 4.7663 - val_loss: 19.3526 - val_y1_output_loss: 7.6175 - val_y2_output_loss: 11.0515 - val_y1_output_root_mean_squared_error: 2.8068 - val_y2_output_root_mean_squared_error: 3.3874
# Epoch 10/500
# 614/614 [==============================] - 0s 150us/sample - loss: 21.9407 - y1_output_loss: 8.5828 - y2_output_loss: 13.2126 - y1_output_root_mean_squared_error: 2.9403 - y2_output_root_mean_squared_error: 3.6462 - val_loss: 13.6285 - val_y1_output_loss: 5.2366 - val_y2_output_loss: 8.0654 - val_y1_output_root_mean_squared_error: 2.3189 - val_y2_output_root_mean_squared_error: 2.8725
# Epoch 11/500
# 614/614 [==============================] - 0s 164us/sample - loss: 24.9633 - y1_output_loss: 8.5130 - y2_output_loss: 16.6130 - y1_output_root_mean_squared_error: 2.9165 - y2_output_root_mean_squared_error: 4.0567 - val_loss: 85.1098 - val_y1_output_loss: 16.7096 - val_y2_output_loss: 67.6378 - val_y1_output_root_mean_squared_error: 4.1138 - val_y2_output_root_mean_squared_error: 8.2575
# Epoch 12/500
# 614/614 [==============================] - 0s 157us/sample - loss: 21.8165 - y1_output_loss: 8.0534 - y2_output_loss: 13.6292 - y1_output_root_mean_squared_error: 2.8481 - y2_output_root_mean_squared_error: 3.7020 - val_loss: 10.4201 - val_y1_output_loss: 4.8573 - val_y2_output_loss: 5.2320 - val_y1_output_root_mean_squared_error: 2.2378 - val_y2_output_root_mean_squared_error: 2.3265
# Epoch 13/500
# 614/614 [==============================] - 0s 149us/sample - loss: 17.9873 - y1_output_loss: 7.1507 - y2_output_loss: 10.7660 - y1_output_root_mean_squared_error: 2.6796 - y2_output_root_mean_squared_error: 3.2874 - val_loss: 17.8724 - val_y1_output_loss: 6.2235 - val_y2_output_loss: 11.0247 - val_y1_output_root_mean_squared_error: 2.5370 - val_y2_output_root_mean_squared_error: 3.3817
# Epoch 14/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.0241 - y1_output_loss: 6.9747 - y2_output_loss: 9.9939 - y1_output_root_mean_squared_error: 2.6420 - y2_output_root_mean_squared_error: 3.1692 - val_loss: 10.2214 - val_y1_output_loss: 4.9703 - val_y2_output_loss: 4.9529 - val_y1_output_root_mean_squared_error: 2.2576 - val_y2_output_root_mean_squared_error: 2.2638
# Epoch 15/500
# 614/614 [==============================] - 0s 150us/sample - loss: 19.7944 - y1_output_loss: 6.9595 - y2_output_loss: 12.8738 - y1_output_root_mean_squared_error: 2.6397 - y2_output_root_mean_squared_error: 3.5814 - val_loss: 18.0797 - val_y1_output_loss: 4.9657 - val_y2_output_loss: 12.7337 - val_y1_output_root_mean_squared_error: 2.2628 - val_y2_output_root_mean_squared_error: 3.5999
# Epoch 16/500
# 614/614 [==============================] - 0s 164us/sample - loss: 18.7044 - y1_output_loss: 6.7801 - y2_output_loss: 11.7506 - y1_output_root_mean_squared_error: 2.6161 - y2_output_root_mean_squared_error: 3.4439 - val_loss: 11.0552 - val_y1_output_loss: 5.0757 - val_y2_output_loss: 5.7538 - val_y1_output_root_mean_squared_error: 2.2751 - val_y2_output_root_mean_squared_error: 2.4247
# Epoch 17/500
# 614/614 [==============================] - 0s 154us/sample - loss: 17.5486 - y1_output_loss: 6.3391 - y2_output_loss: 11.1007 - y1_output_root_mean_squared_error: 2.5236 - y2_output_root_mean_squared_error: 3.3437 - val_loss: 11.1742 - val_y1_output_loss: 5.3608 - val_y2_output_loss: 5.4660 - val_y1_output_root_mean_squared_error: 2.3537 - val_y2_output_root_mean_squared_error: 2.3737
# Epoch 18/500
# 614/614 [==============================] - 0s 154us/sample - loss: 16.2665 - y1_output_loss: 5.7730 - y2_output_loss: 10.5006 - y1_output_root_mean_squared_error: 2.4014 - y2_output_root_mean_squared_error: 3.2404 - val_loss: 9.8124 - val_y1_output_loss: 4.6055 - val_y2_output_loss: 4.9047 - val_y1_output_root_mean_squared_error: 2.1789 - val_y2_output_root_mean_squared_error: 2.2505
# Epoch 19/500
# 614/614 [==============================] - 0s 158us/sample - loss: 20.6688 - y1_output_loss: 6.5318 - y2_output_loss: 14.0901 - y1_output_root_mean_squared_error: 2.5511 - y2_output_root_mean_squared_error: 3.7631 - val_loss: 14.1784 - val_y1_output_loss: 5.6584 - val_y2_output_loss: 8.1158 - val_y1_output_root_mean_squared_error: 2.4085 - val_y2_output_root_mean_squared_error: 2.8944
# Epoch 20/500
# 614/614 [==============================] - 0s 153us/sample - loss: 14.4544 - y1_output_loss: 5.5980 - y2_output_loss: 9.1134 - y1_output_root_mean_squared_error: 2.3667 - y2_output_root_mean_squared_error: 2.9755 - val_loss: 11.2183 - val_y1_output_loss: 4.5013 - val_y2_output_loss: 6.4803 - val_y1_output_root_mean_squared_error: 2.1598 - val_y2_output_root_mean_squared_error: 2.5600
# Epoch 21/500
# 614/614 [==============================] - 0s 153us/sample - loss: 18.8089 - y1_output_loss: 6.1923 - y2_output_loss: 12.4622 - y1_output_root_mean_squared_error: 2.4961 - y2_output_root_mean_squared_error: 3.5466 - val_loss: 8.7919 - val_y1_output_loss: 3.5128 - val_y2_output_loss: 5.0407 - val_y1_output_root_mean_squared_error: 1.8918 - val_y2_output_root_mean_squared_error: 2.2832
# Epoch 22/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.8662 - y1_output_loss: 4.5099 - y2_output_loss: 7.2836 - y1_output_root_mean_squared_error: 2.1306 - y2_output_root_mean_squared_error: 2.7068 - val_loss: 10.5517 - val_y1_output_loss: 3.7609 - val_y2_output_loss: 6.4212 - val_y1_output_root_mean_squared_error: 1.9709 - val_y2_output_root_mean_squared_error: 2.5821
# Epoch 23/500
# 614/614 [==============================] - 0s 155us/sample - loss: 12.4015 - y1_output_loss: 4.4718 - y2_output_loss: 7.9908 - y1_output_root_mean_squared_error: 2.1201 - y2_output_root_mean_squared_error: 2.8119 - val_loss: 30.9113 - val_y1_output_loss: 6.7481 - val_y2_output_loss: 23.7410 - val_y1_output_root_mean_squared_error: 2.6222 - val_y2_output_root_mean_squared_error: 4.9026
# Epoch 24/500
# 614/614 [==============================] - 0s 157us/sample - loss: 12.2845 - y1_output_loss: 4.2036 - y2_output_loss: 8.0177 - y1_output_root_mean_squared_error: 2.0580 - y2_output_root_mean_squared_error: 2.8371 - val_loss: 9.5518 - val_y1_output_loss: 3.1056 - val_y2_output_loss: 6.3620 - val_y1_output_root_mean_squared_error: 1.7807 - val_y2_output_root_mean_squared_error: 2.5261
# Epoch 25/500
# 614/614 [==============================] - 0s 151us/sample - loss: 12.9655 - y1_output_loss: 4.3240 - y2_output_loss: 8.5285 - y1_output_root_mean_squared_error: 2.0892 - y2_output_root_mean_squared_error: 2.9327 - val_loss: 19.8077 - val_y1_output_loss: 2.8209 - val_y2_output_loss: 16.6471 - val_y1_output_root_mean_squared_error: 1.7049 - val_y2_output_root_mean_squared_error: 4.1111
# Epoch 26/500
# 614/614 [==============================] - 0s 145us/sample - loss: 12.2760 - y1_output_loss: 3.9848 - y2_output_loss: 8.4285 - y1_output_root_mean_squared_error: 1.9841 - y2_output_root_mean_squared_error: 2.8878 - val_loss: 28.7879 - val_y1_output_loss: 10.5675 - val_y2_output_loss: 17.3382 - val_y1_output_root_mean_squared_error: 3.3029 - val_y2_output_root_mean_squared_error: 4.2283
# Epoch 27/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.0746 - y1_output_loss: 3.8220 - y2_output_loss: 7.2006 - y1_output_root_mean_squared_error: 1.9565 - y2_output_root_mean_squared_error: 2.6920 - val_loss: 7.2199 - val_y1_output_loss: 2.4947 - val_y2_output_loss: 4.4617 - val_y1_output_root_mean_squared_error: 1.6081 - val_y2_output_root_mean_squared_error: 2.1527
# Epoch 28/500
# 614/614 [==============================] - 0s 145us/sample - loss: 11.5127 - y1_output_loss: 3.7040 - y2_output_loss: 7.8798 - y1_output_root_mean_squared_error: 1.9142 - y2_output_root_mean_squared_error: 2.8015 - val_loss: 32.4691 - val_y1_output_loss: 8.4689 - val_y2_output_loss: 23.0940 - val_y1_output_root_mean_squared_error: 2.9533 - val_y2_output_root_mean_squared_error: 4.8731
# Epoch 29/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.6756 - y1_output_loss: 3.1606 - y2_output_loss: 6.4279 - y1_output_root_mean_squared_error: 1.7862 - y2_output_root_mean_squared_error: 2.5466 - val_loss: 6.6315 - val_y1_output_loss: 2.4489 - val_y2_output_loss: 4.0241 - val_y1_output_root_mean_squared_error: 1.5854 - val_y2_output_root_mean_squared_error: 2.0293
# Epoch 30/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.6212 - y1_output_loss: 2.9134 - y2_output_loss: 5.7524 - y1_output_root_mean_squared_error: 1.7033 - y2_output_root_mean_squared_error: 2.3916 - val_loss: 9.6877 - val_y1_output_loss: 2.8398 - val_y2_output_loss: 6.5312 - val_y1_output_root_mean_squared_error: 1.7139 - val_y2_output_root_mean_squared_error: 2.5981
# Epoch 31/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.8186 - y1_output_loss: 2.6621 - y2_output_loss: 5.2239 - y1_output_root_mean_squared_error: 1.6332 - y2_output_root_mean_squared_error: 2.2697 - val_loss: 30.6024 - val_y1_output_loss: 6.9330 - val_y2_output_loss: 23.2851 - val_y1_output_root_mean_squared_error: 2.6521 - val_y2_output_root_mean_squared_error: 4.8548
# Epoch 32/500
# 614/614 [==============================] - 0s 151us/sample - loss: 11.5351 - y1_output_loss: 3.6977 - y2_output_loss: 7.9046 - y1_output_root_mean_squared_error: 1.9124 - y2_output_root_mean_squared_error: 2.8067 - val_loss: 32.2596 - val_y1_output_loss: 8.7930 - val_y2_output_loss: 22.4970 - val_y1_output_root_mean_squared_error: 3.0135 - val_y2_output_root_mean_squared_error: 4.8144
# Epoch 33/500
# 614/614 [==============================] - 0s 158us/sample - loss: 13.4536 - y1_output_loss: 4.1067 - y2_output_loss: 9.3279 - y1_output_root_mean_squared_error: 2.0332 - y2_output_root_mean_squared_error: 3.0528 - val_loss: 15.4032 - val_y1_output_loss: 3.7242 - val_y2_output_loss: 11.5061 - val_y1_output_root_mean_squared_error: 1.9442 - val_y2_output_root_mean_squared_error: 3.4093
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.9565 - y1_output_loss: 2.6624 - y2_output_loss: 5.2811 - y1_output_root_mean_squared_error: 1.6359 - y2_output_root_mean_squared_error: 2.2979 - val_loss: 9.7147 - val_y1_output_loss: 2.7150 - val_y2_output_loss: 6.7004 - val_y1_output_root_mean_squared_error: 1.6782 - val_y2_output_root_mean_squared_error: 2.6265
# Epoch 35/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.5779 - y1_output_loss: 2.4334 - y2_output_loss: 5.2952 - y1_output_root_mean_squared_error: 1.5425 - y2_output_root_mean_squared_error: 2.2800 - val_loss: 18.4808 - val_y1_output_loss: 4.7096 - val_y2_output_loss: 13.2044 - val_y1_output_root_mean_squared_error: 2.2065 - val_y2_output_root_mean_squared_error: 3.6894
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.5028 - y1_output_loss: 3.1034 - y2_output_loss: 6.3388 - y1_output_root_mean_squared_error: 1.7664 - y2_output_root_mean_squared_error: 2.5264 - val_loss: 5.8561 - val_y1_output_loss: 2.0523 - val_y2_output_loss: 3.6709 - val_y1_output_root_mean_squared_error: 1.4493 - val_y2_output_root_mean_squared_error: 1.9379
# Epoch 37/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.3786 - y1_output_loss: 2.6227 - y2_output_loss: 5.7429 - y1_output_root_mean_squared_error: 1.6111 - y2_output_root_mean_squared_error: 2.4048 - val_loss: 13.0764 - val_y1_output_loss: 6.0656 - val_y2_output_loss: 6.5454 - val_y1_output_root_mean_squared_error: 2.5058 - val_y2_output_root_mean_squared_error: 2.6071
# Epoch 38/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.7199 - y1_output_loss: 2.5259 - y2_output_loss: 5.1625 - y1_output_root_mean_squared_error: 1.5940 - y2_output_root_mean_squared_error: 2.2758 - val_loss: 7.8774 - val_y1_output_loss: 2.9672 - val_y2_output_loss: 4.7944 - val_y1_output_root_mean_squared_error: 1.7443 - val_y2_output_root_mean_squared_error: 2.1988
# Epoch 39/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.5228 - y1_output_loss: 2.5449 - y2_output_loss: 5.9632 - y1_output_root_mean_squared_error: 1.5978 - y2_output_root_mean_squared_error: 2.4433 - val_loss: 7.4458 - val_y1_output_loss: 2.1865 - val_y2_output_loss: 5.1135 - val_y1_output_root_mean_squared_error: 1.4966 - val_y2_output_root_mean_squared_error: 2.2816
# Epoch 40/500
# 614/614 [==============================] - 0s 155us/sample - loss: 9.2709 - y1_output_loss: 2.8664 - y2_output_loss: 6.5184 - y1_output_root_mean_squared_error: 1.6720 - y2_output_root_mean_squared_error: 2.5446 - val_loss: 26.4085 - val_y1_output_loss: 8.5489 - val_y2_output_loss: 16.9914 - val_y1_output_root_mean_squared_error: 2.9739 - val_y2_output_root_mean_squared_error: 4.1910
# Epoch 41/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.0075 - y1_output_loss: 2.6618 - y2_output_loss: 5.4171 - y1_output_root_mean_squared_error: 1.6267 - y2_output_root_mean_squared_error: 2.3155 - val_loss: 5.3775 - val_y1_output_loss: 1.6943 - val_y2_output_loss: 3.5359 - val_y1_output_root_mean_squared_error: 1.3215 - val_y2_output_root_mean_squared_error: 1.9056
# Epoch 42/500
# 614/614 [==============================] - 0s 167us/sample - loss: 7.3586 - y1_output_loss: 2.0856 - y2_output_loss: 5.2270 - y1_output_root_mean_squared_error: 1.4505 - y2_output_root_mean_squared_error: 2.2923 - val_loss: 5.3129 - val_y1_output_loss: 1.7506 - val_y2_output_loss: 3.4656 - val_y1_output_root_mean_squared_error: 1.3311 - val_y2_output_root_mean_squared_error: 1.8818
# Epoch 43/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.3518 - y1_output_loss: 2.1560 - y2_output_loss: 5.2944 - y1_output_root_mean_squared_error: 1.4712 - y2_output_root_mean_squared_error: 2.2776 - val_loss: 24.9876 - val_y1_output_loss: 4.4652 - val_y2_output_loss: 20.3058 - val_y1_output_root_mean_squared_error: 2.1209 - val_y2_output_root_mean_squared_error: 4.5265
# Epoch 44/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.3227 - y1_output_loss: 2.3981 - y2_output_loss: 5.8843 - y1_output_root_mean_squared_error: 1.5547 - y2_output_root_mean_squared_error: 2.4301 - val_loss: 6.5302 - val_y1_output_loss: 1.8586 - val_y2_output_loss: 4.4964 - val_y1_output_root_mean_squared_error: 1.3860 - val_y2_output_root_mean_squared_error: 2.1469
# Epoch 45/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.2678 - y1_output_loss: 1.9303 - y2_output_loss: 4.3413 - y1_output_root_mean_squared_error: 1.3842 - y2_output_root_mean_squared_error: 2.0861 - val_loss: 7.6207 - val_y1_output_loss: 2.5309 - val_y2_output_loss: 4.8643 - val_y1_output_root_mean_squared_error: 1.6130 - val_y2_output_root_mean_squared_error: 2.2403
# Epoch 46/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.1046 - y1_output_loss: 2.8787 - y2_output_loss: 7.2136 - y1_output_root_mean_squared_error: 1.6954 - y2_output_root_mean_squared_error: 2.6889 - val_loss: 12.8057 - val_y1_output_loss: 5.3737 - val_y2_output_loss: 7.1355 - val_y1_output_root_mean_squared_error: 2.3493 - val_y2_output_root_mean_squared_error: 2.6994
# Epoch 47/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.7368 - y1_output_loss: 2.2118 - y2_output_loss: 5.5463 - y1_output_root_mean_squared_error: 1.4898 - y2_output_root_mean_squared_error: 2.3489 - val_loss: 8.1336 - val_y1_output_loss: 1.7280 - val_y2_output_loss: 6.3393 - val_y1_output_root_mean_squared_error: 1.3255 - val_y2_output_root_mean_squared_error: 2.5252
# Epoch 48/500
# 614/614 [==============================] - 0s 162us/sample - loss: 8.1858 - y1_output_loss: 2.4333 - y2_output_loss: 5.7125 - y1_output_root_mean_squared_error: 1.5604 - y2_output_root_mean_squared_error: 2.3981 - val_loss: 7.2774 - val_y1_output_loss: 2.2909 - val_y2_output_loss: 4.7242 - val_y1_output_root_mean_squared_error: 1.5416 - val_y2_output_root_mean_squared_error: 2.2138
# Epoch 49/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.2309 - y1_output_loss: 2.2846 - y2_output_loss: 5.9008 - y1_output_root_mean_squared_error: 1.5153 - y2_output_root_mean_squared_error: 2.4362 - val_loss: 15.0006 - val_y1_output_loss: 5.1429 - val_y2_output_loss: 9.3426 - val_y1_output_root_mean_squared_error: 2.3083 - val_y2_output_root_mean_squared_error: 3.1101
# Epoch 50/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.2363 - y1_output_loss: 1.8105 - y2_output_loss: 4.4663 - y1_output_root_mean_squared_error: 1.3389 - y2_output_root_mean_squared_error: 2.1080 - val_loss: 7.8165 - val_y1_output_loss: 1.8549 - val_y2_output_loss: 5.7130 - val_y1_output_root_mean_squared_error: 1.3838 - val_y2_output_root_mean_squared_error: 2.4293
# Epoch 51/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.5808 - y1_output_loss: 1.8626 - y2_output_loss: 4.7297 - y1_output_root_mean_squared_error: 1.3623 - y2_output_root_mean_squared_error: 2.1737 - val_loss: 6.2183 - val_y1_output_loss: 2.2782 - val_y2_output_loss: 3.7631 - val_y1_output_root_mean_squared_error: 1.5307 - val_y2_output_root_mean_squared_error: 1.9686
# Epoch 52/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.0854 - y1_output_loss: 1.7411 - y2_output_loss: 4.2881 - y1_output_root_mean_squared_error: 1.3257 - y2_output_root_mean_squared_error: 2.0804 - val_loss: 4.7592 - val_y1_output_loss: 1.4592 - val_y2_output_loss: 3.1939 - val_y1_output_root_mean_squared_error: 1.2199 - val_y2_output_root_mean_squared_error: 1.8086
# Epoch 53/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.8847 - y1_output_loss: 1.7432 - y2_output_loss: 4.2178 - y1_output_root_mean_squared_error: 1.3124 - y2_output_root_mean_squared_error: 2.0401 - val_loss: 13.9975 - val_y1_output_loss: 3.1721 - val_y2_output_loss: 10.9038 - val_y1_output_root_mean_squared_error: 1.7709 - val_y2_output_root_mean_squared_error: 3.2957
# Epoch 54/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.2009 - y1_output_loss: 1.9566 - y2_output_loss: 5.1856 - y1_output_root_mean_squared_error: 1.4051 - y2_output_root_mean_squared_error: 2.2862 - val_loss: 8.6149 - val_y1_output_loss: 2.0857 - val_y2_output_loss: 6.4086 - val_y1_output_root_mean_squared_error: 1.4611 - val_y2_output_root_mean_squared_error: 2.5456
# Epoch 55/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.6569 - y1_output_loss: 1.8808 - y2_output_loss: 4.7152 - y1_output_root_mean_squared_error: 1.3776 - y2_output_root_mean_squared_error: 2.1815 - val_loss: 4.7955 - val_y1_output_loss: 1.4386 - val_y2_output_loss: 3.2009 - val_y1_output_root_mean_squared_error: 1.2192 - val_y2_output_root_mean_squared_error: 1.8191
# Epoch 56/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.0291 - y1_output_loss: 1.7329 - y2_output_loss: 4.3189 - y1_output_root_mean_squared_error: 1.3126 - y2_output_root_mean_squared_error: 2.0751 - val_loss: 21.8519 - val_y1_output_loss: 8.5683 - val_y2_output_loss: 12.9046 - val_y1_output_root_mean_squared_error: 2.9481 - val_y2_output_root_mean_squared_error: 3.6278
# Epoch 57/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.4668 - y1_output_loss: 1.9305 - y2_output_loss: 4.4973 - y1_output_root_mean_squared_error: 1.3927 - y2_output_root_mean_squared_error: 2.1277 - val_loss: 6.2373 - val_y1_output_loss: 2.1132 - val_y2_output_loss: 4.0115 - val_y1_output_root_mean_squared_error: 1.4657 - val_y2_output_root_mean_squared_error: 2.0221
# Epoch 58/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.9317 - y1_output_loss: 2.0824 - y2_output_loss: 4.8018 - y1_output_root_mean_squared_error: 1.4438 - y2_output_root_mean_squared_error: 2.2016 - val_loss: 4.8295 - val_y1_output_loss: 1.9387 - val_y2_output_loss: 2.7969 - val_y1_output_root_mean_squared_error: 1.4124 - val_y2_output_root_mean_squared_error: 1.6836
# Epoch 59/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.2245 - y1_output_loss: 1.8488 - y2_output_loss: 4.3833 - y1_output_root_mean_squared_error: 1.3643 - y2_output_root_mean_squared_error: 2.0888 - val_loss: 6.8464 - val_y1_output_loss: 1.7018 - val_y2_output_loss: 5.0759 - val_y1_output_root_mean_squared_error: 1.3180 - val_y2_output_root_mean_squared_error: 2.2603
# Epoch 60/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.3036 - y1_output_loss: 1.4984 - y2_output_loss: 3.7568 - y1_output_root_mean_squared_error: 1.2296 - y2_output_root_mean_squared_error: 1.9472 - val_loss: 7.3844 - val_y1_output_loss: 2.9439 - val_y2_output_loss: 4.2244 - val_y1_output_root_mean_squared_error: 1.7418 - val_y2_output_root_mean_squared_error: 2.0858
# Epoch 61/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.0876 - y1_output_loss: 1.2933 - y2_output_loss: 3.7857 - y1_output_root_mean_squared_error: 1.1419 - y2_output_root_mean_squared_error: 1.9452 - val_loss: 7.7599 - val_y1_output_loss: 1.6430 - val_y2_output_loss: 6.0528 - val_y1_output_root_mean_squared_error: 1.2904 - val_y2_output_root_mean_squared_error: 2.4688
# Epoch 62/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.2884 - y1_output_loss: 1.6537 - y2_output_loss: 4.5990 - y1_output_root_mean_squared_error: 1.2920 - y2_output_root_mean_squared_error: 2.1492 - val_loss: 6.8077 - val_y1_output_loss: 1.3249 - val_y2_output_loss: 5.5621 - val_y1_output_root_mean_squared_error: 1.1403 - val_y2_output_root_mean_squared_error: 2.3468
# Epoch 63/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.3464 - y1_output_loss: 1.7746 - y2_output_loss: 5.5491 - y1_output_root_mean_squared_error: 1.3358 - y2_output_root_mean_squared_error: 2.3584 - val_loss: 4.7877 - val_y1_output_loss: 1.3623 - val_y2_output_loss: 3.4376 - val_y1_output_root_mean_squared_error: 1.1659 - val_y2_output_root_mean_squared_error: 1.8516
# Epoch 64/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.6539 - y1_output_loss: 1.2431 - y2_output_loss: 3.4110 - y1_output_root_mean_squared_error: 1.1144 - y2_output_root_mean_squared_error: 1.8471 - val_loss: 9.4951 - val_y1_output_loss: 1.8475 - val_y2_output_loss: 7.3140 - val_y1_output_root_mean_squared_error: 1.3840 - val_y2_output_root_mean_squared_error: 2.7531
# Epoch 65/500
# 614/614 [==============================] - 0s 144us/sample - loss: 17.4892 - y1_output_loss: 5.4148 - y2_output_loss: 11.9173 - y1_output_root_mean_squared_error: 2.3374 - y2_output_root_mean_squared_error: 3.4678 - val_loss: 4.0518 - val_y1_output_loss: 0.9554 - val_y2_output_loss: 3.1349 - val_y1_output_root_mean_squared_error: 0.9721 - val_y2_output_root_mean_squared_error: 1.7626
# Epoch 66/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.5770 - y1_output_loss: 1.0755 - y2_output_loss: 3.4620 - y1_output_root_mean_squared_error: 1.0417 - y2_output_root_mean_squared_error: 1.8686 - val_loss: 4.6894 - val_y1_output_loss: 1.2931 - val_y2_output_loss: 3.2393 - val_y1_output_root_mean_squared_error: 1.1535 - val_y2_output_root_mean_squared_error: 1.8327
# Epoch 67/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.7171 - y1_output_loss: 1.1196 - y2_output_loss: 3.5607 - y1_output_root_mean_squared_error: 1.0631 - y2_output_root_mean_squared_error: 1.8939 - val_loss: 4.0404 - val_y1_output_loss: 1.1713 - val_y2_output_loss: 2.8498 - val_y1_output_root_mean_squared_error: 1.0830 - val_y2_output_root_mean_squared_error: 1.6934
# Epoch 68/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.0062 - y1_output_loss: 0.9201 - y2_output_loss: 3.0603 - y1_output_root_mean_squared_error: 0.9631 - y2_output_root_mean_squared_error: 1.7546 - val_loss: 3.7312 - val_y1_output_loss: 1.0570 - val_y2_output_loss: 2.5675 - val_y1_output_root_mean_squared_error: 1.0430 - val_y2_output_root_mean_squared_error: 1.6258
# Epoch 69/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.7399 - y1_output_loss: 1.7817 - y2_output_loss: 4.9285 - y1_output_root_mean_squared_error: 1.3362 - y2_output_root_mean_squared_error: 2.2259 - val_loss: 6.8470 - val_y1_output_loss: 1.7174 - val_y2_output_loss: 4.9029 - val_y1_output_root_mean_squared_error: 1.3310 - val_y2_output_root_mean_squared_error: 2.2529
# Epoch 70/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.7843 - y1_output_loss: 1.2200 - y2_output_loss: 3.5337 - y1_output_root_mean_squared_error: 1.1040 - y2_output_root_mean_squared_error: 1.8883 - val_loss: 3.5573 - val_y1_output_loss: 0.8444 - val_y2_output_loss: 2.5974 - val_y1_output_root_mean_squared_error: 0.9305 - val_y2_output_root_mean_squared_error: 1.6406
# Epoch 71/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.1928 - y1_output_loss: 1.1219 - y2_output_loss: 4.3102 - y1_output_root_mean_squared_error: 1.0480 - y2_output_root_mean_squared_error: 2.0235 - val_loss: 4.6650 - val_y1_output_loss: 1.3373 - val_y2_output_loss: 3.2566 - val_y1_output_root_mean_squared_error: 1.1651 - val_y2_output_root_mean_squared_error: 1.8187
# Epoch 72/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.8953 - y1_output_loss: 0.9393 - y2_output_loss: 2.9330 - y1_output_root_mean_squared_error: 0.9679 - y2_output_root_mean_squared_error: 1.7200 - val_loss: 8.7852 - val_y1_output_loss: 3.2116 - val_y2_output_loss: 5.3130 - val_y1_output_root_mean_squared_error: 1.8143 - val_y2_output_root_mean_squared_error: 2.3438
# Epoch 73/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.6282 - y1_output_loss: 0.8134 - y2_output_loss: 2.7919 - y1_output_root_mean_squared_error: 0.9037 - y2_output_root_mean_squared_error: 1.6768 - val_loss: 3.0778 - val_y1_output_loss: 0.9016 - val_y2_output_loss: 2.0929 - val_y1_output_root_mean_squared_error: 0.9639 - val_y2_output_root_mean_squared_error: 1.4659
# Epoch 74/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.8460 - y1_output_loss: 0.9190 - y2_output_loss: 2.9472 - y1_output_root_mean_squared_error: 0.9627 - y2_output_root_mean_squared_error: 1.7085 - val_loss: 4.9403 - val_y1_output_loss: 0.9785 - val_y2_output_loss: 3.8209 - val_y1_output_root_mean_squared_error: 0.9971 - val_y2_output_root_mean_squared_error: 1.9865
# Epoch 75/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.9695 - y1_output_loss: 1.8694 - y2_output_loss: 5.0753 - y1_output_root_mean_squared_error: 1.3655 - y2_output_root_mean_squared_error: 2.2594 - val_loss: 2.9047 - val_y1_output_loss: 0.7354 - val_y2_output_loss: 2.1676 - val_y1_output_root_mean_squared_error: 0.8560 - val_y2_output_root_mean_squared_error: 1.4737
# Epoch 76/500
# 614/614 [==============================] - 0s 164us/sample - loss: 4.5862 - y1_output_loss: 1.1415 - y2_output_loss: 3.7343 - y1_output_root_mean_squared_error: 1.0468 - y2_output_root_mean_squared_error: 1.8682 - val_loss: 15.0535 - val_y1_output_loss: 6.7446 - val_y2_output_loss: 7.8209 - val_y1_output_root_mean_squared_error: 2.6391 - val_y2_output_root_mean_squared_error: 2.8441
# Epoch 77/500
# 614/614 [==============================] - 0s 154us/sample - loss: 3.7321 - y1_output_loss: 0.9210 - y2_output_loss: 2.7769 - y1_output_root_mean_squared_error: 0.9642 - y2_output_root_mean_squared_error: 1.6740 - val_loss: 2.7640 - val_y1_output_loss: 0.6238 - val_y2_output_loss: 2.1258 - val_y1_output_root_mean_squared_error: 0.7887 - val_y2_output_root_mean_squared_error: 1.4635
# Epoch 78/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.5577 - y1_output_loss: 0.7774 - y2_output_loss: 2.7638 - y1_output_root_mean_squared_error: 0.8838 - y2_output_root_mean_squared_error: 1.6663 - val_loss: 3.1627 - val_y1_output_loss: 0.9874 - val_y2_output_loss: 2.1044 - val_y1_output_root_mean_squared_error: 1.0060 - val_y2_output_root_mean_squared_error: 1.4665
# Epoch 79/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.6900 - y1_output_loss: 1.1637 - y2_output_loss: 3.6747 - y1_output_root_mean_squared_error: 1.0777 - y2_output_root_mean_squared_error: 1.8784 - val_loss: 62.3888 - val_y1_output_loss: 16.1753 - val_y2_output_loss: 44.4802 - val_y1_output_root_mean_squared_error: 4.0885 - val_y2_output_root_mean_squared_error: 6.7582
# Epoch 80/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.1569 - y1_output_loss: 1.6738 - y2_output_loss: 4.5024 - y1_output_root_mean_squared_error: 1.2977 - y2_output_root_mean_squared_error: 2.1149 - val_loss: 8.5312 - val_y1_output_loss: 1.1910 - val_y2_output_loss: 7.1012 - val_y1_output_root_mean_squared_error: 1.1036 - val_y2_output_root_mean_squared_error: 2.7043
# Epoch 81/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9444 - y1_output_loss: 0.9818 - y2_output_loss: 3.1602 - y1_output_root_mean_squared_error: 0.9658 - y2_output_root_mean_squared_error: 1.7354 - val_loss: 41.5128 - val_y1_output_loss: 13.4362 - val_y2_output_loss: 27.0879 - val_y1_output_root_mean_squared_error: 3.7139 - val_y2_output_root_mean_squared_error: 5.2650
# Epoch 82/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.4071 - y1_output_loss: 1.9164 - y2_output_loss: 5.4328 - y1_output_root_mean_squared_error: 1.3864 - y2_output_root_mean_squared_error: 2.3420 - val_loss: 4.5625 - val_y1_output_loss: 1.8795 - val_y2_output_loss: 2.5574 - val_y1_output_root_mean_squared_error: 1.3934 - val_y2_output_root_mean_squared_error: 1.6189
# Epoch 83/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.6344 - y1_output_loss: 1.6170 - y2_output_loss: 5.0379 - y1_output_root_mean_squared_error: 1.2681 - y2_output_root_mean_squared_error: 2.2419 - val_loss: 14.3572 - val_y1_output_loss: 4.9112 - val_y2_output_loss: 8.9680 - val_y1_output_root_mean_squared_error: 2.2518 - val_y2_output_root_mean_squared_error: 3.0474
# Epoch 84/500
# 614/614 [==============================] - 0s 155us/sample - loss: 3.6563 - y1_output_loss: 1.0077 - y2_output_loss: 2.6199 - y1_output_root_mean_squared_error: 1.0085 - y2_output_root_mean_squared_error: 1.6245 - val_loss: 2.8702 - val_y1_output_loss: 0.6605 - val_y2_output_loss: 2.1510 - val_y1_output_root_mean_squared_error: 0.8237 - val_y2_output_root_mean_squared_error: 1.4805
# Epoch 85/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.9366 - y1_output_loss: 0.8835 - y2_output_loss: 3.0541 - y1_output_root_mean_squared_error: 0.9399 - y2_output_root_mean_squared_error: 1.7474 - val_loss: 4.3487 - val_y1_output_loss: 0.7414 - val_y2_output_loss: 3.5688 - val_y1_output_root_mean_squared_error: 0.8625 - val_y2_output_root_mean_squared_error: 1.8986
# Epoch 86/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.3824 - y1_output_loss: 0.7666 - y2_output_loss: 2.6179 - y1_output_root_mean_squared_error: 0.8653 - y2_output_root_mean_squared_error: 1.6229 - val_loss: 5.8265 - val_y1_output_loss: 2.4326 - val_y2_output_loss: 3.2209 - val_y1_output_root_mean_squared_error: 1.5760 - val_y2_output_root_mean_squared_error: 1.8283
# Epoch 87/500
# 614/614 [==============================] - 0s 161us/sample - loss: 5.7240 - y1_output_loss: 1.4310 - y2_output_loss: 4.3481 - y1_output_root_mean_squared_error: 1.1982 - y2_output_root_mean_squared_error: 2.0709 - val_loss: 9.1779 - val_y1_output_loss: 1.9283 - val_y2_output_loss: 7.3546 - val_y1_output_root_mean_squared_error: 1.3785 - val_y2_output_root_mean_squared_error: 2.6977
# Epoch 88/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.1104 - y1_output_loss: 1.0123 - y2_output_loss: 3.0844 - y1_output_root_mean_squared_error: 1.0032 - y2_output_root_mean_squared_error: 1.7618 - val_loss: 2.5519 - val_y1_output_loss: 0.7781 - val_y2_output_loss: 1.7468 - val_y1_output_root_mean_squared_error: 0.8860 - val_y2_output_root_mean_squared_error: 1.3293
# Epoch 89/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.3220 - y1_output_loss: 1.3198 - y2_output_loss: 3.9785 - y1_output_root_mean_squared_error: 1.1440 - y2_output_root_mean_squared_error: 2.0033 - val_loss: 3.9686 - val_y1_output_loss: 0.7058 - val_y2_output_loss: 3.1298 - val_y1_output_root_mean_squared_error: 0.8496 - val_y2_output_root_mean_squared_error: 1.8019
# Epoch 90/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.0190 - y1_output_loss: 0.9081 - y2_output_loss: 3.1137 - y1_output_root_mean_squared_error: 0.9571 - y2_output_root_mean_squared_error: 1.7615 - val_loss: 5.0115 - val_y1_output_loss: 0.7793 - val_y2_output_loss: 4.1786 - val_y1_output_root_mean_squared_error: 0.8933 - val_y2_output_root_mean_squared_error: 2.0527
# Epoch 91/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.9960 - y1_output_loss: 0.8027 - y2_output_loss: 3.1568 - y1_output_root_mean_squared_error: 0.8998 - y2_output_root_mean_squared_error: 1.7850 - val_loss: 3.0523 - val_y1_output_loss: 0.8412 - val_y2_output_loss: 2.1630 - val_y1_output_root_mean_squared_error: 0.9299 - val_y2_output_root_mean_squared_error: 1.4790
# Epoch 92/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.9728 - y1_output_loss: 0.9019 - y2_output_loss: 3.0381 - y1_output_root_mean_squared_error: 0.9518 - y2_output_root_mean_squared_error: 1.7512 - val_loss: 2.5416 - val_y1_output_loss: 0.6852 - val_y2_output_loss: 1.7871 - val_y1_output_root_mean_squared_error: 0.8385 - val_y2_output_root_mean_squared_error: 1.3559
# Epoch 93/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.8042 - y1_output_loss: 0.5813 - y2_output_loss: 2.2593 - y1_output_root_mean_squared_error: 0.7569 - y2_output_root_mean_squared_error: 1.4938 - val_loss: 4.9322 - val_y1_output_loss: 1.2444 - val_y2_output_loss: 3.5232 - val_y1_output_root_mean_squared_error: 1.1311 - val_y2_output_root_mean_squared_error: 1.9112
# Epoch 94/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.6329 - y1_output_loss: 0.5358 - y2_output_loss: 2.0789 - y1_output_root_mean_squared_error: 0.7339 - y2_output_root_mean_squared_error: 1.4472 - val_loss: 2.4505 - val_y1_output_loss: 0.6878 - val_y2_output_loss: 1.7260 - val_y1_output_root_mean_squared_error: 0.8361 - val_y2_output_root_mean_squared_error: 1.3234
# Epoch 95/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.4246 - y1_output_loss: 0.8208 - y2_output_loss: 2.6415 - y1_output_root_mean_squared_error: 0.9087 - y2_output_root_mean_squared_error: 1.6121 - val_loss: 10.8502 - val_y1_output_loss: 0.7206 - val_y2_output_loss: 9.9865 - val_y1_output_root_mean_squared_error: 0.8582 - val_y2_output_root_mean_squared_error: 3.1802
# Epoch 96/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.5536 - y1_output_loss: 0.4865 - y2_output_loss: 2.0596 - y1_output_root_mean_squared_error: 0.6974 - y2_output_root_mean_squared_error: 1.4378 - val_loss: 2.7324 - val_y1_output_loss: 0.6449 - val_y2_output_loss: 2.0507 - val_y1_output_root_mean_squared_error: 0.8129 - val_y2_output_root_mean_squared_error: 1.4393
# Epoch 97/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3510 - y1_output_loss: 0.7538 - y2_output_loss: 2.5707 - y1_output_root_mean_squared_error: 0.8717 - y2_output_root_mean_squared_error: 1.6097 - val_loss: 2.2180 - val_y1_output_loss: 0.4533 - val_y2_output_loss: 1.7100 - val_y1_output_root_mean_squared_error: 0.6769 - val_y2_output_root_mean_squared_error: 1.3266
# Epoch 98/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.5348 - y1_output_loss: 0.8155 - y2_output_loss: 2.6898 - y1_output_root_mean_squared_error: 0.9056 - y2_output_root_mean_squared_error: 1.6477 - val_loss: 2.0372 - val_y1_output_loss: 0.4634 - val_y2_output_loss: 1.5400 - val_y1_output_root_mean_squared_error: 0.6840 - val_y2_output_root_mean_squared_error: 1.2527
# Epoch 99/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5445 - y1_output_loss: 0.5120 - y2_output_loss: 2.0259 - y1_output_root_mean_squared_error: 0.7187 - y2_output_root_mean_squared_error: 1.4241 - val_loss: 4.2680 - val_y1_output_loss: 1.4929 - val_y2_output_loss: 2.6342 - val_y1_output_root_mean_squared_error: 1.2401 - val_y2_output_root_mean_squared_error: 1.6523
# Epoch 100/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0824 - y1_output_loss: 0.9918 - y2_output_loss: 3.0593 - y1_output_root_mean_squared_error: 0.9978 - y2_output_root_mean_squared_error: 1.7569 - val_loss: 2.0762 - val_y1_output_loss: 0.5004 - val_y2_output_loss: 1.5474 - val_y1_output_root_mean_squared_error: 0.7106 - val_y2_output_root_mean_squared_error: 1.2535
# Epoch 101/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9031 - y1_output_loss: 0.6645 - y2_output_loss: 2.3850 - y1_output_root_mean_squared_error: 0.8086 - y2_output_root_mean_squared_error: 1.4998 - val_loss: 32.9189 - val_y1_output_loss: 7.3442 - val_y2_output_loss: 24.8666 - val_y1_output_root_mean_squared_error: 2.7498 - val_y2_output_root_mean_squared_error: 5.0356
# Epoch 102/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.0116 - y1_output_loss: 2.7004 - y2_output_loss: 6.2630 - y1_output_root_mean_squared_error: 1.6501 - y2_output_root_mean_squared_error: 2.5077 - val_loss: 11.2935 - val_y1_output_loss: 0.5441 - val_y2_output_loss: 10.6740 - val_y1_output_root_mean_squared_error: 0.7434 - val_y2_output_root_mean_squared_error: 3.2773
# Epoch 103/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.6796 - y1_output_loss: 1.3667 - y2_output_loss: 4.2853 - y1_output_root_mean_squared_error: 1.1720 - y2_output_root_mean_squared_error: 2.0751 - val_loss: 3.0472 - val_y1_output_loss: 0.4244 - val_y2_output_loss: 2.5287 - val_y1_output_root_mean_squared_error: 0.6576 - val_y2_output_root_mean_squared_error: 1.6170
# Epoch 104/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9117 - y1_output_loss: 0.6346 - y2_output_loss: 2.2755 - y1_output_root_mean_squared_error: 0.7969 - y2_output_root_mean_squared_error: 1.5089 - val_loss: 4.7816 - val_y1_output_loss: 0.8141 - val_y2_output_loss: 3.8238 - val_y1_output_root_mean_squared_error: 0.9132 - val_y2_output_root_mean_squared_error: 1.9869
# Epoch 105/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.1010 - y1_output_loss: 0.6613 - y2_output_loss: 2.4285 - y1_output_root_mean_squared_error: 0.8138 - y2_output_root_mean_squared_error: 1.5616 - val_loss: 3.8797 - val_y1_output_loss: 0.4432 - val_y2_output_loss: 3.4062 - val_y1_output_root_mean_squared_error: 0.6726 - val_y2_output_root_mean_squared_error: 1.8513
# Epoch 106/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.1849 - y1_output_loss: 0.9181 - y2_output_loss: 3.2740 - y1_output_root_mean_squared_error: 0.9588 - y2_output_root_mean_squared_error: 1.8071 - val_loss: 2.6783 - val_y1_output_loss: 0.6547 - val_y2_output_loss: 1.9428 - val_y1_output_root_mean_squared_error: 0.8221 - val_y2_output_root_mean_squared_error: 1.4151
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9602 - y1_output_loss: 0.7147 - y2_output_loss: 2.2474 - y1_output_root_mean_squared_error: 0.8478 - y2_output_root_mean_squared_error: 1.4972 - val_loss: 5.7629 - val_y1_output_loss: 1.1131 - val_y2_output_loss: 4.4861 - val_y1_output_root_mean_squared_error: 1.0673 - val_y2_output_root_mean_squared_error: 2.1503
# Epoch 108/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7665 - y1_output_loss: 0.6297 - y2_output_loss: 2.1548 - y1_output_root_mean_squared_error: 0.7886 - y2_output_root_mean_squared_error: 1.4644 - val_loss: 4.0218 - val_y1_output_loss: 0.6409 - val_y2_output_loss: 3.3413 - val_y1_output_root_mean_squared_error: 0.8085 - val_y2_output_root_mean_squared_error: 1.8352
# Epoch 109/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.0332 - y1_output_loss: 0.4473 - y2_output_loss: 1.5959 - y1_output_root_mean_squared_error: 0.6682 - y2_output_root_mean_squared_error: 1.2596 - val_loss: 5.9953 - val_y1_output_loss: 0.6186 - val_y2_output_loss: 5.3885 - val_y1_output_root_mean_squared_error: 0.7911 - val_y2_output_root_mean_squared_error: 2.3172
# Epoch 110/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6045 - y1_output_loss: 0.5508 - y2_output_loss: 2.0652 - y1_output_root_mean_squared_error: 0.7363 - y2_output_root_mean_squared_error: 1.4361 - val_loss: 3.3919 - val_y1_output_loss: 1.0877 - val_y2_output_loss: 2.3178 - val_y1_output_root_mean_squared_error: 1.0557 - val_y2_output_root_mean_squared_error: 1.5091
# Epoch 111/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.8996 - y1_output_loss: 2.7658 - y2_output_loss: 6.0780 - y1_output_root_mean_squared_error: 1.6678 - y2_output_root_mean_squared_error: 2.4734 - val_loss: 2.4444 - val_y1_output_loss: 0.7887 - val_y2_output_loss: 1.6246 - val_y1_output_root_mean_squared_error: 0.8997 - val_y2_output_root_mean_squared_error: 1.2786
# Epoch 112/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.1795 - y1_output_loss: 0.6178 - y2_output_loss: 2.5421 - y1_output_root_mean_squared_error: 0.7862 - y2_output_root_mean_squared_error: 1.6004 - val_loss: 3.7830 - val_y1_output_loss: 1.4153 - val_y2_output_loss: 2.4187 - val_y1_output_root_mean_squared_error: 1.1916 - val_y2_output_root_mean_squared_error: 1.5372
# Epoch 113/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6005 - y1_output_loss: 0.5231 - y2_output_loss: 2.0619 - y1_output_root_mean_squared_error: 0.7246 - y2_output_root_mean_squared_error: 1.4407 - val_loss: 3.3213 - val_y1_output_loss: 0.4379 - val_y2_output_loss: 2.9208 - val_y1_output_root_mean_squared_error: 0.6626 - val_y2_output_root_mean_squared_error: 1.6977
# Epoch 114/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0524 - y1_output_loss: 0.4858 - y2_output_loss: 1.5592 - y1_output_root_mean_squared_error: 0.6976 - y2_output_root_mean_squared_error: 1.2513 - val_loss: 3.4243 - val_y1_output_loss: 1.0826 - val_y2_output_loss: 2.3151 - val_y1_output_root_mean_squared_error: 1.0495 - val_y2_output_root_mean_squared_error: 1.5241
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0185 - y1_output_loss: 0.6109 - y2_output_loss: 2.3852 - y1_output_root_mean_squared_error: 0.7832 - y2_output_root_mean_squared_error: 1.5508 - val_loss: 1.8869 - val_y1_output_loss: 0.5136 - val_y2_output_loss: 1.3547 - val_y1_output_root_mean_squared_error: 0.7242 - val_y2_output_root_mean_squared_error: 1.1673
# Epoch 116/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5429 - y1_output_loss: 0.5313 - y2_output_loss: 1.9954 - y1_output_root_mean_squared_error: 0.7313 - y2_output_root_mean_squared_error: 1.4171 - val_loss: 3.3978 - val_y1_output_loss: 1.2263 - val_y2_output_loss: 2.1210 - val_y1_output_root_mean_squared_error: 1.1242 - val_y2_output_root_mean_squared_error: 1.4608
# Epoch 117/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6065 - y1_output_loss: 0.5736 - y2_output_loss: 2.0189 - y1_output_root_mean_squared_error: 0.7558 - y2_output_root_mean_squared_error: 1.4267 - val_loss: 2.0584 - val_y1_output_loss: 0.6158 - val_y2_output_loss: 1.3897 - val_y1_output_root_mean_squared_error: 0.7949 - val_y2_output_root_mean_squared_error: 1.1943
# Epoch 118/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.5483 - y1_output_loss: 0.5984 - y2_output_loss: 2.0182 - y1_output_root_mean_squared_error: 0.7719 - y2_output_root_mean_squared_error: 1.3973 - val_loss: 4.3693 - val_y1_output_loss: 1.2330 - val_y2_output_loss: 3.0065 - val_y1_output_root_mean_squared_error: 1.1246 - val_y2_output_root_mean_squared_error: 1.7620
# Epoch 119/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.5867 - y1_output_loss: 0.6350 - y2_output_loss: 1.9885 - y1_output_root_mean_squared_error: 0.7991 - y2_output_root_mean_squared_error: 1.3957 - val_loss: 2.0533 - val_y1_output_loss: 0.6780 - val_y2_output_loss: 1.4065 - val_y1_output_root_mean_squared_error: 0.8185 - val_y2_output_root_mean_squared_error: 1.1762
# Epoch 120/500
# 614/614 [==============================] - 0s 141us/sample - loss: 1.9736 - y1_output_loss: 0.4005 - y2_output_loss: 1.5820 - y1_output_root_mean_squared_error: 0.6355 - y2_output_root_mean_squared_error: 1.2529 - val_loss: 1.8306 - val_y1_output_loss: 0.4801 - val_y2_output_loss: 1.3502 - val_y1_output_root_mean_squared_error: 0.6951 - val_y2_output_root_mean_squared_error: 1.1608
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4667 - y1_output_loss: 0.1273 - y2_output_loss: 0.3371 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5822 - val_loss: 0.8714 - val_y1_output_loss: 0.2469 - val_y2_output_loss: 0.6105 - val_y1_output_root_mean_squared_error: 0.5039 - val_y2_output_root_mean_squared_error: 0.7858
# Epoch 462/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4907 - y1_output_loss: 0.1427 - y2_output_loss: 0.3465 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.5907 - val_loss: 0.7942 - val_y1_output_loss: 0.2119 - val_y2_output_loss: 0.5639 - val_y1_output_root_mean_squared_error: 0.4661 - val_y2_output_root_mean_squared_error: 0.7596
# Epoch 463/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4746 - y1_output_loss: 0.1410 - y2_output_loss: 0.3320 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.5769 - val_loss: 0.9110 - val_y1_output_loss: 0.2596 - val_y2_output_loss: 0.6568 - val_y1_output_root_mean_squared_error: 0.5148 - val_y2_output_root_mean_squared_error: 0.8038
# Epoch 464/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4058 - y1_output_loss: 0.1180 - y2_output_loss: 0.2863 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5358 - val_loss: 0.8292 - val_y1_output_loss: 0.2213 - val_y2_output_loss: 0.5893 - val_y1_output_root_mean_squared_error: 0.4768 - val_y2_output_root_mean_squared_error: 0.7758
# Epoch 465/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.5120 - y1_output_loss: 0.1275 - y2_output_loss: 0.3802 - y1_output_root_mean_squared_error: 0.3584 - y2_output_root_mean_squared_error: 0.6193 - val_loss: 0.7929 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.5653 - val_y1_output_root_mean_squared_error: 0.4598 - val_y2_output_root_mean_squared_error: 0.7626
# Epoch 466/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4577 - y1_output_loss: 0.1293 - y2_output_loss: 0.3297 - y1_output_root_mean_squared_error: 0.3603 - y2_output_root_mean_squared_error: 0.5726 - val_loss: 1.5340 - val_y1_output_loss: 0.3448 - val_y2_output_loss: 1.1620 - val_y1_output_root_mean_squared_error: 0.5956 - val_y2_output_root_mean_squared_error: 1.0859
# Epoch 467/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.7429 - y1_output_loss: 0.1968 - y2_output_loss: 0.5402 - y1_output_root_mean_squared_error: 0.4448 - y2_output_root_mean_squared_error: 0.7382 - val_loss: 0.8092 - val_y1_output_loss: 0.2424 - val_y2_output_loss: 0.5456 - val_y1_output_root_mean_squared_error: 0.4975 - val_y2_output_root_mean_squared_error: 0.7495
# Epoch 468/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4171 - y1_output_loss: 0.1258 - y2_output_loss: 0.2994 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5392 - val_loss: 2.2056 - val_y1_output_loss: 0.2664 - val_y2_output_loss: 1.8750 - val_y1_output_root_mean_squared_error: 0.5189 - val_y2_output_root_mean_squared_error: 1.3915
# Epoch 469/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5317 - y1_output_loss: 0.1396 - y2_output_loss: 0.3948 - y1_output_root_mean_squared_error: 0.3737 - y2_output_root_mean_squared_error: 0.6262 - val_loss: 1.0386 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 0.7865 - val_y1_output_root_mean_squared_error: 0.5049 - val_y2_output_root_mean_squared_error: 0.8852
# Epoch 470/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5744 - y1_output_loss: 0.1377 - y2_output_loss: 0.4327 - y1_output_root_mean_squared_error: 0.3727 - y2_output_root_mean_squared_error: 0.6599 - val_loss: 0.8466 - val_y1_output_loss: 0.2133 - val_y2_output_loss: 0.6119 - val_y1_output_root_mean_squared_error: 0.4660 - val_y2_output_root_mean_squared_error: 0.7934
# Epoch 471/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5066 - y1_output_loss: 0.1306 - y2_output_loss: 0.3719 - y1_output_root_mean_squared_error: 0.3625 - y2_output_root_mean_squared_error: 0.6125 - val_loss: 0.8538 - val_y1_output_loss: 0.2617 - val_y2_output_loss: 0.5688 - val_y1_output_root_mean_squared_error: 0.5182 - val_y2_output_root_mean_squared_error: 0.7651
# Epoch 472/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.5793 - y1_output_loss: 0.1237 - y2_output_loss: 0.4518 - y1_output_root_mean_squared_error: 0.3530 - y2_output_root_mean_squared_error: 0.6743 - val_loss: 0.9349 - val_y1_output_loss: 0.2292 - val_y2_output_loss: 0.6914 - val_y1_output_root_mean_squared_error: 0.4850 - val_y2_output_root_mean_squared_error: 0.8365
# Epoch 473/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4993 - y1_output_loss: 0.1287 - y2_output_loss: 0.3674 - y1_output_root_mean_squared_error: 0.3597 - y2_output_root_mean_squared_error: 0.6082 - val_loss: 0.8385 - val_y1_output_loss: 0.2601 - val_y2_output_loss: 0.5550 - val_y1_output_root_mean_squared_error: 0.5182 - val_y2_output_root_mean_squared_error: 0.7550
# Epoch 474/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4554 - y1_output_loss: 0.1368 - y2_output_loss: 0.3226 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5661 - val_loss: 1.1059 - val_y1_output_loss: 0.2504 - val_y2_output_loss: 0.8497 - val_y1_output_root_mean_squared_error: 0.5083 - val_y2_output_root_mean_squared_error: 0.9206
# Epoch 475/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.7491 - y1_output_loss: 0.1829 - y2_output_loss: 0.5721 - y1_output_root_mean_squared_error: 0.4290 - y2_output_root_mean_squared_error: 0.7517 - val_loss: 1.0496 - val_y1_output_loss: 0.2477 - val_y2_output_loss: 0.7673 - val_y1_output_root_mean_squared_error: 0.5065 - val_y2_output_root_mean_squared_error: 0.8905
# Epoch 476/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4360 - y1_output_loss: 0.1201 - y2_output_loss: 0.3131 - y1_output_root_mean_squared_error: 0.3479 - y2_output_root_mean_squared_error: 0.5612 - val_loss: 0.7681 - val_y1_output_loss: 0.2189 - val_y2_output_loss: 0.5294 - val_y1_output_root_mean_squared_error: 0.4744 - val_y2_output_root_mean_squared_error: 0.7369
# Epoch 477/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4676 - y1_output_loss: 0.1356 - y2_output_loss: 0.3340 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5795 - val_loss: 1.0524 - val_y1_output_loss: 0.3552 - val_y2_output_loss: 0.6822 - val_y1_output_root_mean_squared_error: 0.6044 - val_y2_output_root_mean_squared_error: 0.8289
# Epoch 478/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4592 - y1_output_loss: 0.1273 - y2_output_loss: 0.3293 - y1_output_root_mean_squared_error: 0.3582 - y2_output_root_mean_squared_error: 0.5752 - val_loss: 1.1226 - val_y1_output_loss: 0.2781 - val_y2_output_loss: 0.8089 - val_y1_output_root_mean_squared_error: 0.5324 - val_y2_output_root_mean_squared_error: 0.9160
# Epoch 479/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4580 - y1_output_loss: 0.1065 - y2_output_loss: 0.3538 - y1_output_root_mean_squared_error: 0.3263 - y2_output_root_mean_squared_error: 0.5929 - val_loss: 0.8841 - val_y1_output_loss: 0.2115 - val_y2_output_loss: 0.6493 - val_y1_output_root_mean_squared_error: 0.4657 - val_y2_output_root_mean_squared_error: 0.8168
# Epoch 480/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5308 - y1_output_loss: 0.1332 - y2_output_loss: 0.3952 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.6303 - val_loss: 1.2453 - val_y1_output_loss: 0.3944 - val_y2_output_loss: 0.8259 - val_y1_output_root_mean_squared_error: 0.6380 - val_y2_output_root_mean_squared_error: 0.9155
# Epoch 481/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.6212 - y1_output_loss: 0.1550 - y2_output_loss: 0.4663 - y1_output_root_mean_squared_error: 0.3905 - y2_output_root_mean_squared_error: 0.6846 - val_loss: 0.9546 - val_y1_output_loss: 0.2598 - val_y2_output_loss: 0.7004 - val_y1_output_root_mean_squared_error: 0.5143 - val_y2_output_root_mean_squared_error: 0.8308
# Epoch 482/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3899 - y1_output_loss: 0.1203 - y2_output_loss: 0.2806 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 1.1783 - val_y1_output_loss: 0.3955 - val_y2_output_loss: 0.7530 - val_y1_output_root_mean_squared_error: 0.6311 - val_y2_output_root_mean_squared_error: 0.8832
# Epoch 483/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4757 - y1_output_loss: 0.1420 - y2_output_loss: 0.3310 - y1_output_root_mean_squared_error: 0.3776 - y2_output_root_mean_squared_error: 0.5772 - val_loss: 0.8211 - val_y1_output_loss: 0.2217 - val_y2_output_loss: 0.5781 - val_y1_output_root_mean_squared_error: 0.4743 - val_y2_output_root_mean_squared_error: 0.7721
# Epoch 484/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5511 - y1_output_loss: 0.1507 - y2_output_loss: 0.3990 - y1_output_root_mean_squared_error: 0.3898 - y2_output_root_mean_squared_error: 0.6318 - val_loss: 0.9060 - val_y1_output_loss: 0.2288 - val_y2_output_loss: 0.6587 - val_y1_output_root_mean_squared_error: 0.4836 - val_y2_output_root_mean_squared_error: 0.8198
# Epoch 485/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4748 - y1_output_loss: 0.1264 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5897 - val_loss: 0.7654 - val_y1_output_loss: 0.2150 - val_y2_output_loss: 0.5350 - val_y1_output_root_mean_squared_error: 0.4703 - val_y2_output_root_mean_squared_error: 0.7377
# Epoch 486/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5324 - y1_output_loss: 0.1411 - y2_output_loss: 0.3903 - y1_output_root_mean_squared_error: 0.3763 - y2_output_root_mean_squared_error: 0.6251 - val_loss: 0.9669 - val_y1_output_loss: 0.2153 - val_y2_output_loss: 0.7326 - val_y1_output_root_mean_squared_error: 0.4708 - val_y2_output_root_mean_squared_error: 0.8633
# Epoch 487/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4764 - y1_output_loss: 0.1120 - y2_output_loss: 0.3631 - y1_output_root_mean_squared_error: 0.3344 - y2_output_root_mean_squared_error: 0.6038 - val_loss: 1.0388 - val_y1_output_loss: 0.3507 - val_y2_output_loss: 0.6542 - val_y1_output_root_mean_squared_error: 0.6005 - val_y2_output_root_mean_squared_error: 0.8235
# Epoch 488/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4884 - y1_output_loss: 0.1413 - y2_output_loss: 0.3455 - y1_output_root_mean_squared_error: 0.3745 - y2_output_root_mean_squared_error: 0.5901 - val_loss: 0.9434 - val_y1_output_loss: 0.3515 - val_y2_output_loss: 0.5679 - val_y1_output_root_mean_squared_error: 0.6025 - val_y2_output_root_mean_squared_error: 0.7619
# Epoch 489/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.5024 - y1_output_loss: 0.1335 - y2_output_loss: 0.3683 - y1_output_root_mean_squared_error: 0.3661 - y2_output_root_mean_squared_error: 0.6070 - val_loss: 1.3582 - val_y1_output_loss: 0.3485 - val_y2_output_loss: 0.9905 - val_y1_output_root_mean_squared_error: 0.5990 - val_y2_output_root_mean_squared_error: 0.9997
# Epoch 490/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4301 - y1_output_loss: 0.1166 - y2_output_loss: 0.3114 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.5596 - val_loss: 0.7823 - val_y1_output_loss: 0.2206 - val_y2_output_loss: 0.5463 - val_y1_output_root_mean_squared_error: 0.4730 - val_y2_output_root_mean_squared_error: 0.7474
# Epoch 491/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4897 - y1_output_loss: 0.1487 - y2_output_loss: 0.3414 - y1_output_root_mean_squared_error: 0.3850 - y2_output_root_mean_squared_error: 0.5843 - val_loss: 0.9419 - val_y1_output_loss: 0.2773 - val_y2_output_loss: 0.6478 - val_y1_output_root_mean_squared_error: 0.5340 - val_y2_output_root_mean_squared_error: 0.8104
# Epoch 492/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4711 - y1_output_loss: 0.1316 - y2_output_loss: 0.3648 - y1_output_root_mean_squared_error: 0.3552 - y2_output_root_mean_squared_error: 0.5873 - val_loss: 3.7286 - val_y1_output_loss: 1.0281 - val_y2_output_loss: 2.5770 - val_y1_output_root_mean_squared_error: 1.0297 - val_y2_output_root_mean_squared_error: 1.6335
# Epoch 493/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.5200 - y1_output_loss: 0.1520 - y2_output_loss: 0.3663 - y1_output_root_mean_squared_error: 0.3885 - y2_output_root_mean_squared_error: 0.6075 - val_loss: 0.9732 - val_y1_output_loss: 0.2732 - val_y2_output_loss: 0.6880 - val_y1_output_root_mean_squared_error: 0.5304 - val_y2_output_root_mean_squared_error: 0.8318
# Epoch 494/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5218 - y1_output_loss: 0.1373 - y2_output_loss: 0.3877 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.6201 - val_loss: 1.3797 - val_y1_output_loss: 0.3259 - val_y2_output_loss: 1.0256 - val_y1_output_root_mean_squared_error: 0.5707 - val_y2_output_root_mean_squared_error: 1.0266
# Epoch 495/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4065 - y1_output_loss: 0.1253 - y2_output_loss: 0.2878 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.5387 - val_loss: 0.9109 - val_y1_output_loss: 0.3267 - val_y2_output_loss: 0.5598 - val_y1_output_root_mean_squared_error: 0.5761 - val_y2_output_root_mean_squared_error: 0.7609
# Epoch 496/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4353 - y1_output_loss: 0.1227 - y2_output_loss: 0.3137 - y1_output_root_mean_squared_error: 0.3479 - y2_output_root_mean_squared_error: 0.5606 - val_loss: 1.1038 - val_y1_output_loss: 0.3298 - val_y2_output_loss: 0.7549 - val_y1_output_root_mean_squared_error: 0.5797 - val_y2_output_root_mean_squared_error: 0.8762
# Epoch 497/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5058 - y1_output_loss: 0.1314 - y2_output_loss: 0.3704 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.6112 - val_loss: 0.8580 - val_y1_output_loss: 0.2318 - val_y2_output_loss: 0.6117 - val_y1_output_root_mean_squared_error: 0.4877 - val_y2_output_root_mean_squared_error: 0.7875
# Epoch 498/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4176 - y1_output_loss: 0.1272 - y2_output_loss: 0.2928 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.5401 - val_loss: 0.8515 - val_y1_output_loss: 0.2652 - val_y2_output_loss: 0.5648 - val_y1_output_root_mean_squared_error: 0.5211 - val_y2_output_root_mean_squared_error: 0.7616
# Epoch 499/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4849 - y1_output_loss: 0.1352 - y2_output_loss: 0.3481 - y1_output_root_mean_squared_error: 0.3658 - y2_output_root_mean_squared_error: 0.5925 - val_loss: 1.0411 - val_y1_output_loss: 0.4211 - val_y2_output_loss: 0.5934 - val_y1_output_root_mean_squared_error: 0.6591 - val_y2_output_root_mean_squared_error: 0.7789
# Epoch 500/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5412 - y1_output_loss: 0.1696 - y2_output_loss: 0.3716 - y1_output_root_mean_squared_error: 0.4081 - y2_output_root_mean_squared_error: 0.6121 - val_loss: 1.0193 - val_y1_output_loss: 0.3590 - val_y2_output_loss: 0.6480 - val_y1_output_root_mean_squared_error: 0.6041 - val_y2_output_root_mean_squared_error: 0.8090

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 40us/sample - loss: 1.0193 - y1_output_loss: 0.3649 - y2_output_loss: 0.6483 - y1_output_root_mean_squared_error: 0.6041 - y2_output_root_mean_squared_error: 0.8090
# Loss = 1.0193290044735004, Y1_loss = 0.3649022579193115, Y1_mse = 0.6040636301040649, Y2_loss = 0.6482558846473694, Y2_mse = 0.8089722990989685

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
